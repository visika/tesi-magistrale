# %%
## import packages and functions
import ase
import numpy as np
from ase.io import read, write #input/output
from ase.visualize import view #visualisation
from ase.calculators.lammpslib import LAMMPSlib #lammps calculator


# LAMMPS calculator
atom_types = {'O' : 2, 'H' : 1}
cmd_nn = [      "#!/bin/bash",
                "variable runnerDir       string \"/scratch/fd385/codes/n2p2/scratch_potentials/h2o/gen007/train_008\"",
                "variable runnerCutoff    equal  8.466835984",
                "pair_style hdnnp ${runnerCutoff} dir ${runnerDir} showew no showewsum 1 resetew yes maxew 200000 cflength 1.889726 cfenergy 0.036749",
                "pair_coeff * * H O",
        ]
LAMMPScalc = LAMMPSlib(atom_types=atom_types, lmpcmds=cmd_nn, tmp_dir="./", log_file='log.lammps', keep_alive=True)

# %%
## LOAD A GEOMETRY AND COMPUTE ITS ENERGY 

atoms=read('POSCAR') #load initial geometry as an atom environment
atoms.calc=LAMMPScalc # attach a calculator

energy=atoms.get_potential_energy() #compute the potential energy (total electronic energy) of the loaded geometry
print('energy: ',energy)
forces=atoms.get_forces() # compute the forces on each atom
print('forces: \n', forces)
# Out:
# energy:  -5635.113732815746
# forces:
#  [[-8.61416416e-04 -1.70265724e-03 -6.73347629e-01]
#  [ 6.67150900e-03 -2.89426891e-03 -6.72835680e-01]
#  [-5.67885723e-03  4.45083970e-03 -6.72650143e-01]
#  [-5.64982928e-03  4.20562679e-04 -6.56982506e-01]
#  [-7.18915773e-03 -1.22745415e-02 -7.26777022e-01]
#  [ 3.10359447e-03 -4.81738876e-03 -6.56845182e-01]
#  [ 6.24258518e-01  6.30486205e-03  2.05072342e-01]
#  [-2.95836272e-01 -5.12887453e-01  2.32648460e-01]
#  [-3.06745851e-01  5.44030139e-01  2.05178558e-01]
#  [-6.17499568e-01  6.28065883e-04  1.96555658e-01]
#  [ 2.95195608e-01  5.11765145e-01  1.93068104e-01]
#  [ 3.09347780e-01 -5.34577777e-01  1.96708730e-01]
#  [ 2.99383345e-01  5.29531424e-01 -2.13856881e-01]
#  [ 2.96883972e-01 -5.28622840e-01 -2.13465755e-01]
#  [ 1.98912944e-01 -1.44261849e-01  6.43718564e-02]
#  [-6.06135099e-01 -7.09428567e-03 -2.13378376e-01]
#  [ 3.08791677e-01  5.24041544e-01 -2.13587213e-01]
#  [-3.14016111e-01  5.27593151e-01 -2.20713574e-01]
#  [-3.01787104e-01 -5.34378182e-01 -2.20802087e-01]
#  [-3.10123019e-01  5.50764465e-01 -2.28688006e-01]
#  [ 6.31881261e-01  6.70232918e-03 -2.28541850e-01]
#  [-3.11797743e-01 -5.28561911e-01 -2.20535323e-01]
#  [ 6.13867077e-01 -8.17957087e-03 -2.20680928e-01]
#  [-2.24279988e-01  1.00140287e-01  6.44045561e-02]
#  [ 2.88812990e-01  5.01351197e-01  4.47333873e-01]
#  [-6.55789886e-01  3.99753159e-02  4.46789579e-01]
#  [ 3.62384458e-01 -5.48239045e-01  4.46518379e-01]
#  [ 6.28786392e-01 -7.45733379e-04  4.53943377e-01]
#  [-3.14900724e-01  5.44300044e-01  4.53671235e-01]
#  [-6.12370201e-01 -1.68953653e-03  4.35540017e-01]
#  [ 3.04948966e-01 -5.31560126e-01  4.35169016e-01]
#  [-2.98354285e-01 -5.16491285e-01  4.62910749e-01]
#  [ 6.16033092e-01 -9.57070774e-03  4.61751503e-01]
#  [-3.16492883e-01  5.29172059e-01  4.61301658e-01]
#  [-3.06926454e-01 -5.32634471e-01  5.92331256e-01]
#  [ 2.31712657e-02  4.00121981e-02 -2.01580752e-01]]

# %%
## PERFORM GEOMETRY OPTIMISATION (KEEPING THE CELL FIXED)

from ase.optimize import BFGS # import the optimiser
from ase.io.trajectory import Trajectory # i/o to save dynamics trajectory

geo=atoms.copy()
geo.calc=LAMMPScalc

#define path to store the trajectory file
path='relax-positions/'

#check if the directory 'relax-positions' exists - if not, create it
import os 
if not os.path.exists(str(path)): 
    os.makedirs(str(path)) 

# run optimisation
dyn = BFGS(geo) # create the optimiser object associated to the atoms  'geo' with calculator 'LAMMPScalc'

traj=Trajectory(path+'simulation.traj','w',geo) # define Trajectory object
dyn.attach(traj) # attach Trajectory to optimiser

dyn.run(fmax=0.03) # relax the atoms position until the forces are < 0.03 ev/Å

# write final (optimised) geometry 
write(images=geo,filename=path+'final.pbd',format='proteindatabank')
# Out:
#       Step     Time          Energy         fmax
# BFGS:    0 10:44:50    -5635.113733        0.8537
# BFGS:    1 10:44:50    -5635.245878        0.2029
# BFGS:    2 10:44:50    -5635.251694        0.1768
# BFGS:    3 10:44:50    -5635.255715        0.1339
# BFGS:    4 10:44:50    -5635.257866        0.0672
# BFGS:    5 10:44:50    -5635.258090        0.0498
# BFGS:    6 10:44:50    -5635.258188        0.0404
# BFGS:    7 10:44:50    -5635.258318        0.0226

# %%
## PERFORM FULL GEOMETRY OPTIMISATION (ATOMS + CELL)

from ase.optimize import QuasiNewton # import the optimiser
from ase.constraints import UnitCellFilter # import the CellFilter object: it's a wrapper that creates an Atoms object with a variable cell
from ase import units #for easier units conversions


#define path to store the trajectory file
path='relax-full/'

#check if the directory 'relax-full' exists - if not, create it
import os 
if not os.path.exists(str(path)): 
    os.makedirs(str(path)) 

for pressure in [0,1]:
    geo=atoms.copy()   # atoms object 
    geo.calc=LAMMPScalc    # attach calculator
    
    ucf = UnitCellFilter(geo,scalar_pressure=pressure*units.GPa) # define the atoms object with variable cell
    qn = QuasiNewton(ucf) # optimiser is defined for the UnitCellFilter not for the initial atoms object!!!
    
    traj = Trajectory(path+'simulation_'+str(pressure)+'GPa.traj', 'w', geo) # define the Trajectory object
    qn.attach(traj) # attach trajectory to optimiser
     
    qn.run(fmax=0.03)
    write(images=geo,filename=path+'/final_P'+str(pressure)+'GPa.pdb',format='proteindatabank')
# Out:
#                 Step[ FC]     Time          Energy          fmax
# *Force-consistent energies used in optimization.
# BFGSLineSearch:    0[  0] 10:45:26    -5635.113733*       0.8537
# BFGSLineSearch:    1[  2] 10:45:26    -5635.246590*       0.1996
# BFGSLineSearch:    2[  4] 10:45:26    -5635.254589*       0.4076
# BFGSLineSearch:    3[  6] 10:45:26    -5635.257774*       0.0779
# BFGSLineSearch:    4[  8] 10:45:26    -5635.257971*       0.0640
# BFGSLineSearch:    5[  9] 10:45:26    -5635.258280*       0.0482
# BFGSLineSearch:    6[ 11] 10:45:26    -5635.258332*       0.0263
#                 Step[ FC]     Time          Energy          fmax
# *Force-consistent energies used in optimization.
# BFGSLineSearch:    0[  0] 10:45:26    -5632.808369*       0.8537
# BFGSLineSearch:    1[  2] 10:45:26    -5632.941912*       0.1987
# BFGSLineSearch:    2[  4] 10:45:26    -5632.950446*       0.4219
# BFGSLineSearch:    3[  6] 10:45:26    -5632.953972*       0.0725
# BFGSLineSearch:    4[  8] 10:45:26    -5632.954464*       0.0959
# BFGSLineSearch:    5[  9] 10:45:27    -5632.956698*       0.0751
# BFGSLineSearch:    6[ 11] 10:45:27    -5632.957385*       0.1575
# BFGSLineSearch:    7[ 13] 10:45:27    -5632.966387*       0.3485
# BFGSLineSearch:    8[ 15] 10:45:27    -5632.972962*       0.1834
# BFGSLineSearch:    9[ 16] 10:45:27    -5632.984853*       0.1483
# BFGSLineSearch:   10[ 18] 10:45:27    -5632.990978*       0.1905
# BFGSLineSearch:   11[ 20] 10:45:27    -5632.998724*       0.1839
# BFGSLineSearch:   12[ 22] 10:45:27    -5633.002871*       0.1724
# BFGSLineSearch:   13[ 23] 10:45:27    -5633.008819*       0.1325
# BFGSLineSearch:   14[ 25] 10:45:27    -5633.011075*       0.0828
# BFGSLineSearch:   15[ 27] 10:45:27    -5633.012582*       0.1075
# BFGSLineSearch:   16[ 29] 10:45:27    -5633.013363*       0.0333
# BFGSLineSearch:   17[ 30] 10:45:27    -5633.013812*       0.0502
# BFGSLineSearch:   18[ 32] 10:45:27    -5633.014268*       0.0302
# BFGSLineSearch:   19[ 34] 10:45:27    -5633.014398*       0.0304
# BFGSLineSearch:   20[ 36] 10:45:28    -5633.014590*       0.0128

# %%
## PHONONS CALCULATION
from ase.phonons import Phonons
from ase.thermochemistry import CrystalThermo


import os, shutil
path = './phonon'
if (os.path.exists(path)):
    shutil.rmtree(path)


geo=read('relax-full/final_P0GPa.pdb') # start from relaxed geometry
geo.calc=LAMMPScalc
potentialenergy=geo.get_potential_energy()

ph = Phonons(geo, LAMMPScalc, supercell=(1, 1, 1), delta=0.02) # compute phonons with small displacement method - set supercell and ∆x (in Å)
ph.run()
ph.read(acoustic=True)
phonon_energies, phonon_DOS = ph.dos(kpts=(10, 10, 10), npts=1000,
                                     delta=5e-4)

# Calculate the Helmholtz free energy
thermo = CrystalThermo(phonon_energies=phonon_energies,
                       phonon_DOS=phonon_DOS,
                       potentialenergy=potentialenergy,
                       formula_units=1)
# Out:
# WARNING, 2 imaginary frequencies at q = (-0.45, -0.45, -0.45) ; (omega_q = 4.480e-04*i)
# WARNING, 2 imaginary frequencies at q = (-0.45, -0.45, -0.35) ; (omega_q = 4.480e-04*i)
# WARNING, 2 imaginary frequencies at q = (-0.45, -0.45, -0.25) ; (omega_q = 4.480e-04*i)
# WARNING, 2 imaginary frequencies at q = (-0.45, -0.45, -0.15) ; (omega_q = 4.480e-04*i)
# WARNING, 2 imaginary frequencies at q = (-0.45, -0.45, -0.05) ; (omega_q = 4.480e-04*i)
# WARNING, 2 imaginary frequencies at q = (-0.45, -0.45,  0.05) ; (omega_q = 4.480e-04*i)
# WARNING, 2 imaginary frequencies at q = (-0.45, -0.45,  0.15) ; (omega_q = 4.480e-04*i)
# WARNING, 2 imaginary frequencies at q = (-0.45, -0.45,  0.25) ; (omega_q = 4.480e-04*i)
# WARNING, 2 imaginary frequencies at q = (-0.45, -0.45,  0.35) ; (omega_q = 4.480e-04*i)
# WARNING, 2 imaginary frequencies at q = (-0.45, -0.45,  0.45) ; (omega_q = 4.480e-04*i)
# WARNING, 2 imaginary frequencies at q = (-0.45, -0.35, -0.45) ; (omega_q = 4.480e-04*i)
# WARNING, 2 imaginary frequencies at q = (-0.45, -0.35, -0.35) ; (omega_q = 4.480e-04*i)
# WARNING, 2 imaginary frequencies at q = (-0.45, -0.35, -0.25) ; (omega_q = 4.480e-04*i)
# WARNING, 2 imaginary frequencies at q = (-0.45, -0.35, -0.15) ; (omega_q = 4.480e-04*i)
# WARNING, 2 imaginary frequencies at q = (-0.45, -0.35, -0.05) ; (omega_q = 4.480e-04*i)
# WARNING, 2 imaginary frequencies at q = (-0.45, -0.35,  0.05) ; (omega_q = 4.480e-04*i)
# WARNING, 2 imaginary frequencies at q = (-0.45, -0.35,  0.15) ; (omega_q = 4.480e-04*i)
# WARNING, 2 imaginary frequencies at q = (-0.45, -0.35,  0.25) ; (omega_q = 4.480e-04*i)
# WARNING, 2 imaginary frequencies at q = (-0.45, -0.35,  0.35) ; (omega_q = 4.480e-04*i)
# WARNING, 2 imaginary frequencies at q = (-0.45, -0.35,  0.45) ; (omega_q = 4.480e-04*i)
# WARNING, 2 imaginary frequencies at q = (-0.45, -0.25, -0.45) ; (omega_q = 4.480e-04*i)
# WARNING, 2 imaginary frequencies at q = (-0.45, -0.25, -0.35) ; (omega_q = 4.480e-04*i)
# WARNING, 2 imaginary frequencies at q = (-0.45, -0.25, -0.25) ; (omega_q = 4.480e-04*i)
# WARNING, 2 imaginary frequencies at q = (-0.45, -0.25, -0.15) ; (omega_q = 4.480e-04*i)
# WARNING, 2 imaginary frequencies at q = (-0.45, -0.25, -0.05) ; (omega_q = 4.480e-04*i)
# WARNING, 2 imaginary frequencies at q = (-0.45, -0.25,  0.05) ; (omega_q = 4.480e-04*i)
# WARNING, 2 imaginary frequencies at q = (-0.45, -0
; (omega_q = 4.480e-04*i)
# WARNING, 2 imaginary frequencies at q = ( 0.45,  0.45,  0.35) ; (omega_q = 4.480e-04*i)
# WARNING, 2 imaginary frequencies at q = ( 0.45,  0.45,  0.45) ; (omega_q = 4.480e-04*i)

# %%
# use the phonons to compute the helmholtz free energy

free=[] # where we save the free energy
for temp in np.arange(10,300,10):
        F = thermo.get_helmholtz_energy(temperature=temp) # exact free energy at a fixed temperature
        free.append([temp,F])
free=np.array(free)

nmol=atoms.get_global_number_of_atoms()/3. #number of water molecules
free[:,1] /= nmol  #free energy per water molecule
# Out:
# Internal energy components at T = 10.00 K,
# on a per-formula-unit basis:
# ===============================
# E_pot             -5635.2583 eV
# E_ZPE                 8.7080 eV
# E_phonon              0.0002 eV
# -------------------------------
# U                 -5626.5500 eV
# ===============================
#
# Entropy components at T = 10.00 K,
# on a per-formula-unit basis:
# =================================================
#                            S               T*S
# -------------------------------------------------
# S                  0.0000462 eV/K       0.0005 eV
# =================================================
#
# Helmholtz free energy components at T = 10.00 K,
# on a per-formula-unit basis:
# =======================
#     U     -5626.5500 eV
#  -T*S        -0.0005 eV
# -----------------------
#     F     -5626.5505 eV
# =======================
# Internal energy components at T = 20.00 K,
# on a per-formula-unit basis:
# ===============================
# E_pot             -5635.2583 eV
# E_ZPE                 8.7080 eV
# E_phonon              0.0010 eV
# -------------------------------
# U                 -5626.5493 eV
# ===============================
#
# Entropy components at T = 20.00 K,
# on a per-formula-unit basis:
# =================================================
#                            S               T*S
# -------------------------------------------------
# S                  0.0000952 eV/K       0.0019 eV
# =================================================
#
# Helmholtz free energy components at T = 20.00 K,
# on a per-formula-unit basis:
# =======================
#     U     -5626.5493 eV
#  -T*S        -0.0019 eV
# -----------------------
#     F     -5626.5512 eV
# =======================
# Internal energy components at T = 30.00 K,
# on a per-formula-unit basis:
# ===============================
# E_pot             -5635.2583 eV
# E_ZPE                 8.7080 eV
# E_phonon              0.0028 eV
# -------------------------------
# U                 -5626.5474 eV
# ===============================
#
# Entropy components at T = 30.00 K,
# on a per-formula-unit basis:
# =================================================
#                            S               T*S
# -------------------------------------------------
# S                  0.0001679 eV/K       0.0050 eV
# =================================================
#
# Helmholtz free energy components at T = 30.00 K,
# on a per-formula-unit basis:
# =======================
#     U     -5626.5474 eV
#  -T*S        -0.0050 eV
# -----------------------
#     F     -5626.5525 eV
# =======================
# Internal energy components at T = 40.00 K,
# on a per-formula-unit basis:
# ===============================
# E_pot             -5635.2583 eV
# E_ZPE                 8.7080 eV
# E_phonon              0.0062 eV
# -------------------------------
# U                 -5626.5440 eV
# ===============================
#
# Entropy components at T = 40.00 K,
# on a per-formula-unit basis:
# =================================================
#                            S               T*S
# -------------------------------------------------
# S                  0.0002649 eV/K       0.0106 eV
# =================================================
#
# Helmholtz free energy components at T = 40.00 K,
# on a per-formula-unit basis:
# =======================
#     U     -5626.5440 eV
#  -T*S        -0.0106 eV
# -----------------------
#     F     -5626.5546 eV
# =======================
# Internal energy components at T = 50.00 K,
# on a per-formula-unit basis:
# ===============================
# E_pot             -5635.2583 eV
# E_ZPE                 8.7080 eV
# E_phonon              0.0114 eV
# -------------------------------
# U                 -5626.5388 eV
# ===============================
#
# Entropy components at T = 50.00 K,
# on a per-formula-unit basis:
# =================================================
#                            S               T*S
# -------------------------------------------------
# S                  0.0003802 eV/K       0.0190 eV
# =================================================
#
# Helmholtz free energy components at T = 50.00 K,
# on a per-formula-unit basis:
# =======================
#     U     -5626.5388 eV
#  -T*S        -0.0190 eV
# -----------------------
#     F     -5626.5578 eV
# =======================
# Internal energy components at T = 60.00 K,
# on a per-formula-unit basis:
# ===============================
# E_pot             -5635.2583 eV
# E_ZPE                 8.7080 eV
# E_phonon              0.0185 eV
# -------------------------------
# U                 -5626.5318 eV
# ===============================
#
# Entropy components at T = 60.00 K,
# on a per-formula-unit basis:
# =================================================
#                            S               T*S
# -------------------------------------------------
# S                  0.0005081 eV/K       0.0305 eV
# =================================================
#
# Helmholtz free energy components at T = 60.00 K,
# on a per-formula-unit basis:
# =======================
#     U     -5626.5318 eV
#  -T*S        -0.0305 eV
# -----------------------
#     F     -5626.5623 eV
# =======================
# Internal energy components at T = 70.00 K,
# on a per-formula-unit basis:
# ===============================
# E_pot             -5635.2583 eV
# E_ZPE                 8.7080 eV
# E_phonon              0.0274 eV
# -------------------------------
# U                 -5626.5229 eV
# ===============================
#
# Entropy components at T = 70.00 K,
# on a per-formula-unit basis:
# =================================================
#                            S               T*S
# -------------------------------------------------
# S                  0.0006447 eV/K       0.0451 eV
# =================================================
#
# Helmholtz free energy components at T = 70.00 K,
# on a per-formula-unit basis:
# =======================
#     U     -5626.5229 eV
#  -T*S        -0.0451 eV
# -----------------------
#     F     -5626.5680 eV
# =======================
# Internal energy components at T = 80.00 K,
# on a per-formula-unit basis:
# ===============================
# E_pot             -5635.2583 eV
# E_ZPE                 8.7080 eV
# E_phonon              0.0380 eV
# -------------------------------
# U                 -5626.5122 eV
# ===============================
#
# Entropy components at T = 80.00 K,
# on a per-formula-unit basis:
# =================================================
#                            S               T*S
# -------------------------------------------------
# S                  0.0007869 eV/K       0.0630 eV
# =================================================
#
# Helmholtz free energy components at T = 80.00 K,
# on a per-formula-unit basis:
# =======================
#     U     -5626.5122 eV
#  -T*S        -0.0630 eV
# -----------------------
#     F     -5626.5752 eV
# =======================
# Internal energy components at T = 90.00 K,
# on a per-formula-unit basis:
# ===============================
# E_pot             -5635.2583 eV
# E_ZPE                 8.7080 eV
# E_phonon              0.0504 eV
# -------------------------------
# U                 -5626.4998 eV
# ===============================
#
# Entropy components at T = 90.00 K,
# on a per-formula-unit basis:
# =================================================
#                            S               T*S
# -------------------------------------------------
# S                  0.0009326 eV/K       0.0839 eV
# =================================================
#
# Helmholtz free energy components at T = 90.00 K,
# on a per-formula-unit basis:
# =======================
#     U     -5626.4998 eV
#  -T*S        -0.0839 eV
# -----------------------
#     F     -5626.5838 eV
# =======================
# Internal energy components at T = 100.00 K,
# on a per-formula-unit basis:
# ===============================
# E_pot             -5635.2583 eV
# E_ZPE                 8.7080 eV
# E_phonon              0.0644 eV
# -------------------------------
# U                 -5626.4858 eV
# ===============================
#
# Entropy components at T = 100.00 K,
# on a per-formula-unit basis:
# =================================================
#                            S               T*S
# -------------------------------------------------
# S                  0.0010798 eV/K       0.1080 eV
# =================================================
#
# Helmholtz free energy components at T = 100.00 K,
# on a per-formula-unit basis:
# =======================
#     U     -5626.4858 eV
#  -T*S        -0.1080 eV
# -----------------------
#     F     -5626.5938 eV
# =======================
# Internal energy components at T = 110.00 K,
# on a per-formula-unit basis:
# ===============================
# E_pot             -5635.2583 eV
# E_ZPE                 8.7080 eV
# E_phonon              0.0799 eV
# -------------------------------
# U                 -5626.4704 eV
# ===============================
#
# Entropy components at T = 110.00 K,
# on a per-formula-unit basis:
# =================================================
#                            S               T*S
# -------------------------------------------------
# S                  0.0012272 eV/K       0.1350 eV
# =================================================
#
# Helmholtz free energy components at T = 110.00 K,
# on a per-formula-unit basis:
# =======================
#     U     -5626.4704 eV
#  -T*S        -0.1350 eV
# -----------------------
#     F     -5626.6054 eV
# =======================
# Internal energy components at T = 120.00 K,
# on a per-formula-unit basis:
# ===============================
# E_pot             -5635.2583 eV
# E_ZPE                 8.7080 eV
# E_phonon              0.0968 eV
# -------------------------------
# U                 -5626.4535 eV
# ===============================
#
# Entropy components at T = 120.00 K,
# on a per-formula-unit basis:
# =================================================
#                            S               T*S
# -------------------------------------------------
# S                  0.0013739 eV/K       0.1649 eV
# =================================================
#
# Helmholtz free energy components at T = 120.00 K,
# on a per-formula-unit basis:
# =======================
#     U     -5626.4535 eV
#  -T*S        -0.1649 eV
# -----------------------
#     F     -5626.6184 eV
# =======================
# Internal energy components at T = 130.00 K,
# on a per-formula-unit basis:
# ===============================
# E_pot             -5635.2583 eV
# E_ZPE                 8.7080 eV
# E_phonon              0.1149 eV
# -------------------------------
# U                 -5626.4353 eV
# ===============================
#
# Entropy components at T = 130.00 K,
# on a per-formula-unit basis:
# =================================================
#                            S               T*S
# -------------------------------------------------
# S                  0.0015193 eV/K       0.1975 eV
# =================================================
#
# Helmholtz free energy components at T = 130.00 K,
# on a per-formula-unit basis:
# =======================
#     U     -5626.4353 eV
#  -T*S        -0.1975 eV
# -----------------------
#     F     -5626.6328 eV
# =======================
# Internal energy components at T = 140.00 K,
# on a per-formula-unit basis:
# ===============================
# E_pot             -5635.2583 eV
# E_ZPE                 8.7080 eV
# E_phonon              0.1343 eV
# -------------------------------
# U                 -5626.4159 eV
# ===============================
#
# Entropy components at T = 140.00 K,
# on a per-formula-unit basis:
# =================================================
#                            S               T*S
# -------------------------------------------------
# S                  0.0016630 eV/K       0.2328 eV
# =================================================
#
# Helmholtz free energy components at T = 140.00 K,
# on a per-formula-unit basis:
# =======================
#     U     -5626.4159 eV
#  -T*S        -0.2328 eV
# -----------------------
#     F     -5626.6488 eV
# =======================
# Internal energy components at T = 150.00 K,
# on a per-formula-unit basis:
# ===============================
# E_pot             -5635.2583 eV
# E_ZPE                 8.7080 eV
# E_phonon              0.1549 eV
# -------------------------------
# U                 -5626.3954 eV
# ===============================
#
# Entropy components at T = 150.00 K,
# on a per-formula-unit basis:
# =================================================
#                            S               T*S
# -------------------------------------------------
# S                  0.0018048 eV/K       0.2707 eV
# =================================================
#
# Helmholtz free energy components at T = 150.00 K,
# on a per-formula-unit basis:
# =======================
#     U     -5626.3954 eV
#  -T*S        -0.2707 eV
# -----------------------
#     F     -5626.6661 eV
# =======================
# Internal energy components at T = 160.00 K,
# on a per-formula-unit basis:
# ===============================
# E_pot             -5635.2583 eV
# E_ZPE                 8.7080 eV
# E_phonon              0.1766 eV
# -------------------------------
# U                 -5626.3737 eV
# ===============================
#
# Entropy components at T = 160.00 K,
# on a per-formula-unit basis:
# =================================================
#                            S               T*S
# -------------------------------------------------
# S                  0.0019447 eV/K       0.3111 eV
# =================================================
#
# Helmholtz free energy components at T = 160.00 K,
# on a per-formula-unit basis:
# =======================
#     U     -5626.3737 eV
#  -T*S        -0.3111 eV
# -----------------------
#     F     -5626.6848 eV
# =======================
# Internal energy components at T = 170.00 K,
# on a per-formula-unit basis:
# ===============================
# E_pot             -5635.2583 eV
# E_ZPE                 8.7080 eV
# E_phonon              0.1993 eV
# -------------------------------
# U                 -5626.3509 eV
# ===============================
#
# Entropy components at T = 170.00 K,
# on a per-formula-unit basis:
# =================================================
#                            S               T*S
# -------------------------------------------------
# S                  0.0020826 eV/K       0.3540 eV
# =================================================
#
# Helmholtz free energy components at T = 170.00 K,
# on a per-formula-unit basis:
# =======================
#     U     -5626.3509 eV
#  -T*S        -0.3540 eV
# -----------------------
#     F     -5626.7050 eV
# =======================
# Internal energy components at T = 180.00 K,
# on a per-formula-unit basis:
# ===============================
# E_pot             -5635.2583 eV
# E_ZPE                 8.7080 eV
# E_phonon              0.2231 eV
# -------------------------------
# U                 -5626.3271 eV
# ===============================
#
# Entropy components at T = 180.00 K,
# on a per-formula-unit basis:
# =================================================
#                            S               T*S
# -------------------------------------------------
# S                  0.0022187 eV/K       0.3994 eV
# =================================================
#
# Helmholtz free energy components at T = 180.00 K,
# on a per-formula-unit basis:
# =======================
#     U     -5626.3271 eV
#  -T*S        -0.3994 eV
# -----------------------
#     F     -5626.7265 eV
# =======================
# Internal energy components at T = 190.00 K,
# on a per-formula-unit basis:
# ===============================
# E_pot             -5635.2583 eV
# E_ZPE                 8.7080 eV
# E_phonon              0.2480 eV
# -------------------------------
# U                 -5626.3023 eV
# ===============================
#
# Entropy components at T = 190.00 K,
# on a per-formula-unit basis:
# =================================================
#                            S               T*S
# -------------------------------------------------
# S                  0.0023531 eV/K       0.4471 eV
# =================================================
#
# Helmholtz free energy components at T = 190.00 K,
# on a per-formula-unit basis:
# =======================
#     U     -5626.3023 eV
#  -T*S        -0.4471 eV
# -----------------------
#     F     -5626.7493 eV
# =======================
# Internal energy components at T = 200.00 K,
# on a per-formula-unit basis:
# ===============================
# E_pot             -5635.2583 eV
# E_ZPE                 8.7080 eV
# E_phonon              0.2739 eV
# -------------------------------
# U                 -5626.2764 eV
# ===============================
#
# Entropy components at T = 200.00 K,
# on a per-formula-unit basis:
# =================================================
#                            S               T*S
# -------------------------------------------------
# S                  0.0024857 eV/K       0.4971 eV
# =================================================
#
# Helmholtz free energy components at T = 200.00 K,
# on a per-formula-unit basis:
# =======================
#     U     -5626.2764 eV
#  -T*S        -0.4971 eV
# -----------------------
#     F     -5626.7735 eV
# =======================
# Internal energy components at T = 210.00 K,
# on a per-formula-unit basis:
# ===============================
# E_pot             -5635.2583 eV
# E_ZPE                 8.7080 eV
# E_phonon              0.3007 eV
# -------------------------------
# U                 -5626.2495 eV
# ===============================
#
# Entropy components at T = 210.00 K,
# on a per-formula-unit basis:
# =================================================
#                            S               T*S
# -------------------------------------------------
# S                  0.0026168 eV/K       0.5495 eV
# =================================================
#
# Helmholtz free energy components at T = 210.00 K,
# on a per-formula-unit basis:
# =======================
#     U     -5626.2495 eV
#  -T*S        -0.5495 eV
# -----------------------
#     F     -5626.7991 eV
# =======================
# Internal energy components at T = 220.00 K,
# on a per-formula-unit basis:
# ===============================
# E_pot             -5635.2583 eV
# E_ZPE                 8.7080 eV
# E_phonon              0.3286 eV
# -------------------------------
# U                 -5626.2217 eV
# ===============================
#
# Entropy components at T = 220.00 K,
# on a per-formula-unit basis:
# =================================================
#                            S               T*S
# -------------------------------------------------
# S                  0.0027464 eV/K       0.6042 eV
# =================================================
#
# Helmholtz free energy components at T = 220.00 K,
# on a per-formula-unit basis:
# =======================
#     U     -5626.2217 eV
#  -T*S        -0.6042 eV
# -----------------------
#     F     -5626.8259 eV
# =======================
# Internal energy components at T = 230.00 K,
# on a per-formula-unit basis:
# ===============================
# E_pot             -5635.2583 eV
# E_ZPE                 8.7080 eV
# E_phonon              0.3574 eV
# -------------------------------
# U                 -5626.1928 eV
# ===============================
#
# Entropy components at T = 230.00 K,
# on a per-formula-unit basis:
# =================================================
#                            S               T*S
# -------------------------------------------------
# S                  0.0028745 eV/K       0.6611 eV
# =================================================
#
# Helmholtz free energy components at T = 230.00 K,
# on a per-formula-unit basis:
# =======================
#     U     -5626.1928 eV
#  -T*S        -0.6611 eV
# -----------------------
#     F     -5626.8540 eV
# =======================
# Internal energy components at T = 240.00 K,
# on a per-formula-unit basis:
# ===============================
# E_pot             -5635.2583 eV
# E_ZPE                 8.7080 eV
# E_phonon              0.3872 eV
# -------------------------------
# U                 -5626.1630 eV
# ===============================
#
# Entropy components at T = 240.00 K,
# on a per-formula-unit basis:
# =================================================
#                            S               T*S
# -------------------------------------------------
# S                  0.0030013 eV/K       0.7203 eV
# =================================================
#
# Helmholtz free energy components at T = 240.00 K,
# on a per-formula-unit basis:
# =======================
#     U     -5626.1630 eV
#  -T*S        -0.7203 eV
# -----------------------
#     F     -5626.8834 eV
# =======================
# Internal energy components at T = 250.00 K,
# on a per-formula-unit basis:
# ===============================
# E_pot             -5635.2583 eV
# E_ZPE                 8.7080 eV
# E_phonon              0.4180 eV
# -------------------------------
# U                 -5626.1323 eV
# ===============================
#
# Entropy components at T = 250.00 K,
# on a per-formula-unit basis:
# =================================================
#                            S               T*S
# -------------------------------------------------
# S                  0.0031268 eV/K       0.7817 eV
# =================================================
#
# Helmholtz free energy components at T = 250.00 K,
# on a per-formula-unit basis:
# =======================
#     U     -5626.1323 eV
#  -T*S        -0.7817 eV
# -----------------------
#     F     -5626.9140 eV
# =======================
# Internal energy components at T = 260.00 K,
# on a per-formula-unit basis:
# ===============================
# E_pot             -5635.2583 eV
# E_ZPE                 8.7080 eV
# E_phonon              0.4496 eV
# -------------------------------
# U                 -5626.1006 eV
# ===============================
#
# Entropy components at T = 260.00 K,
# on a per-formula-unit basis:
# =================================================
#                            S               T*S
# -------------------------------------------------
# S                  0.0032510 eV/K       0.8453 eV
# =================================================
#
# Helmholtz free energy components at T = 260.00 K,
# on a per-formula-unit basis:
# =======================
#     U     -5626.1006 eV
#  -T*S        -0.8453 eV
# -----------------------
#     F     -5626.9459 eV
# =======================
# Internal energy components at T = 270.00 K,
# on a per-formula-unit basis:
# ===============================
# E_pot             -5635.2583 eV
# E_ZPE                 8.7080 eV
# E_phonon              0.4822 eV
# -------------------------------
# U                 -5626.0680 eV
# ===============================
#
# Entropy components at T = 270.00 K,
# on a per-formula-unit basis:
# =================================================
#                            S               T*S
# -------------------------------------------------
# S                  0.0033740 eV/K       0.9110 eV
# =================================================
#
# Helmholtz free energy components at T = 270.00 K,
# on a per-formula-unit basis:
# =======================
#     U     -5626.0680 eV
#  -T*S        -0.9110 eV
# -----------------------
#     F     -5626.9790 eV
# =======================
# Internal energy components at T = 280.00 K,
# on a per-formula-unit basis:
# ===============================
# E_pot             -5635.2583 eV
# E_ZPE                 8.7080 eV
# E_phonon              0.5157 eV
# -------------------------------
# U                 -5626.0346 eV
# ===============================
#
# Entropy components at T = 280.00 K,
# on a per-formula-unit basis:
# =================================================
#                            S               T*S
# -------------------------------------------------
# S                  0.0034958 eV/K       0.9788 eV
# =================================================
#
# Helmholtz free energy components at T = 280.00 K,
# on a per-formula-unit basis:
# =======================
#     U     -5626.0346 eV
#  -T*S        -0.9788 eV
# -----------------------
#     F     -5627.0134 eV
# =======================
# Internal energy components at T = 290.00 K,
# on a per-formula-unit basis:
# ===============================
# E_pot             -5635.2583 eV
# E_ZPE                 8.7080 eV
# E_phonon              0.5501 eV
# -------------------------------
# U                 -5626.0002 eV
# ===============================
#
# Entropy components at T = 290.00 K,
# on a per-formula-unit basis:
# =================================================
#                            S               T*S
# -------------------------------------------------
# S                  0.0036164 eV/K       1.0487 eV
# =================================================
#
# Helmholtz free energy components at T = 290.00 K,
# on a per-formula-unit basis:
# =======================
#     U     -5626.0002 eV
#  -T*S        -1.0487 eV
# -----------------------
#     F     -5627.0489 eV
# =======================

# %%
## PLOT 

import matplotlib.pyplot as plt
blue='#009fff'

fig, ax = plt.subplots(figsize=(7,4))

ax.plot(free[:,0],free[:,1],linestyle='--',linewidth=2.,marker='o',mec='black',color=blue,markersize=10)

ax.tick_params(direction='out', width=1.5,length=6)

plt.xticks(np.arange(0,325,25),fontsize=14)
plt.yticks(fontsize=14)

plt.ylabel('Free energy [eV/mol]',fontname='arial',fontsize=14,labelpad=8)
plt.xlabel('Temperature [K]',fontname='arial',fontsize=14,labelpad=8)

plt.title('Helmholtz Quasi-Harmonic Free Energy',fontname='arial',fontsize=14)
plt.grid(ls='--',alpha=.3)
plt.tight_layout()
plt.show()

# %%
## liquid water NVT
from ase.md.langevin import Langevin

geo=read('h2o-128.pdb')
#geo=atoms.copy()
geo.calc=LAMMPScalc

#define path to store the trajectory file
path='MD-NVT/'

#check if the directory 'MD-NVT' exists - if not, create it
import os 
if not os.path.exists(str(path)): 
    os.makedirs(str(path)) 

dyn = Langevin(
    geo,
    timestep=1.0 * units.fs, # MD time step in femtoseconds (1.0 fs not accurate)
    temperature_K=300.0,  # temperature in K
    friction=0.01 / units.fs,
    trajectory=path+'simulation.traj',
    loginterval=10
)

dyn.run(1000) # run 1000 MD steps: 1000*0.5 fs = 0.05 ps
# Out:
# True

# %%
## compute Radial Distribution Function
from ase.geometry import analysis
traj=Trajectory('MD-NVT/simulation.traj','r')
rdf=[]

rmax=7
nbins=80 

for i in range(len(traj)):
    geo=traj[i].copy()
    del geo[geo.numbers == 1]
    data=analysis.get_rdf(atoms=geo,rmax=rmax,nbins=nbins)
    rdf.append(data[0])
### average rdf
av_rdf=0
for i in range(len(rdf)):
    av_rdf += rdf[i]/len(rdf)

# %%
### plot rdf

exp=np.loadtxt('rdf-exp',usecols=(0,1))
fig, ax = plt.subplots(figsize=(6,4))

x=np.arange(0,rmax,rmax/nbins)
ax.plot(x,av_rdf,linestyle='-',lw=2.5,c=blue,label='mlp')
ax.plot(exp[:,0],exp[:,1],linestyle='--',lw=2.5,c='red',label='exp')


ax.tick_params(direction='out', width=1.5,length=6)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.ylabel('g$_\mathrm{OO}$(r)',fontname='arial',fontsize=14,labelpad=8)
plt.xlabel('distance [Å]',fontname='arial',fontsize=14,labelpad=8)
plt.title('Radial Distribution Function',fontname='arial',fontsize=14)
plt.grid(ls='--',alpha=.3)
plt.legend(fontsize=14,shadow=True)
plt.tight_layout()
plt.show()
